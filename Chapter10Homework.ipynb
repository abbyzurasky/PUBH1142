# %% [markdown]
# # Chapter 9 Homework

# %% [markdown]
# > Abby Zurasky

# %% [markdown]
# ## Question 1

# %% [markdown]
# #### How do you import the Seaborn package in Python?

# %%
# You import the Seaborn package into Python using the import statement.
# Example:
import seaborn as sns

# %% [markdown]
# ## Question 2

# %% [markdown]
# #### How do you create a scatter plot in Seaborn for variables x and y in DataFrame df?

# %%
# You create a scatter plot using the scatterplot() function.
# Example:
sns.scatterplot(x=[1, 2, 3], y=[4, 5, 6])
# Out:
# <Axes: >

# %% [markdown]
# ## Question 3

# %% [markdown]
# #### How do you create a line plot in Seaborn for the varibales x and y in DataFrame df?

# %%
# You can create a line plot using the lineplot() function.
# Example:
sns.lineplot(x=[1, 2, 3], y=[4, 5, 6])
# Out:
# /Applications/miniconda3/envs/DataScience/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Applications/miniconda3/envs/DataScience/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: >

# %% [markdown]
# ## Question 4

# %% [markdown]
# #### How do you create a histogram in Seabron for a variable x in a DataFrame df?

# %%
# You can create a historgram using the histplot() function.
# Example:
sns.histplot([1, 2, 3, 4, 5, 6])
# Out:
# /Applications/miniconda3/envs/DataScience/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %% [markdown]
# ## Question 5

# %% [markdown]
# #### How do you create a stacked histogram in Seaborn for variables x and 'hue' y in DataFrame df?

# %%
# You can create a stack histogram using the histplot() function with the variables x and 'hue' y
# Example:
# sns.histplot(data=[1, 2, 3, 4, 5, 6], x='x', hue='y')

# %% [markdown]
# ## Question 6

# %% [markdown]
# #### How do you create a heatmap in Seaborn for a variable x and y in DataFrame df?

# %%
# You can create a heatmap in Seaborn for variable x and y using the heatmap() function.
# Example:
sns.heatmap([[1, 2, 3], [4, 5, 6]])
# Out:
# <Axes: >

# %% [markdown]
# ## Question 7

# %% [markdown]
# #### How do you create a box plot in Seaborn for variables x and y in DataFrame df?

# %%
# You can create a boxplot for variables x and y using the boxplot() function.
# Example:
sns.boxplot(x=[1, 2, 3], y=[4, 5, 6])
# Out:
# /Applications/miniconda3/envs/DataScience/lib/python3.12/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# <Axes: >

# %% [markdown]
# ## Question 8

# %% [markdown]
# #### How do you create a violin plot in Seaborn for variables x and y in DataFrame df?

# %%
# You can create a violin plot for variables x and y using the violinplot() function.
# Example:
sns.violinplot(x=[1, 2, 3], y=[4, 5, 6])
# Out:
# /Applications/miniconda3/envs/DataScience/lib/python3.12/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# <Axes: >

# %% [markdown]
# ## Question 9

# %% [markdown]
# #### How do you create a bar plot in Seabron for variables x and y in a DataFrame df?

# %%
# You  can create a bar plot for variables x and y using the barplot() function.
# Example:
sns.barplot(x=[1, 2, 3], y=[4, 5, 6])
# Out:
# /Applications/miniconda3/envs/DataScience/lib/python3.12/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# <Axes: >

# %% [markdown]
# ## Question 10

# %% [markdown]
# #### How do you add a title to a Seaborn plot assigned to the variable x with the title 'My Title'?

# %%
# You can add a title to a plot assigned to the variable x with the title() function.
# Example:
# x.set_title('My Title')

# %% [markdown]
# ## Question 11

# %% [markdown]
# #### How do you save a Seaborn plot ax to a file named 'output.png'?

# %%
# You can save a plot named ax to a file named 'output.png' using the savefig() function.
# Example:
# ax.savefig('output.png')

# %% [markdown]
# ## Question 12

# %% [markdown]
# #### How do you set the x and y axis labels to 'X Label' and 'Y Label' respectively for a Seabron plot ax?

# %%
# You can set the x and y axis labels to 'X Label' and 'Y Label' using the set_xlabel() and set_ylabel() functions.
# Example:
# ax.set_xlabel('X Label')
# ax.set_ylabel('Y Label')

# %% [markdown]
# ## Question 13

# %% [markdown]
# #### How do you change the color palette of a Seaborn function to 'Blues'?

# %%
# You can change the color palette of a plot named ax to 'Blues' using the set_palette() function.
# Example:
# ax.set_palette('Blues')

# %% [markdown]
# ## Question 14

# %% [markdown]
# #### How do you display a Seaborn plot with a logarithmic scale on the y-axis?

# %%
# You can display a Seaborn plot with a logarithmic scale on the y-axis using the set_yscale() function.
# Example:
# ax.set_yscale('log')

# %% [markdown]
# ## Question 15

# %% [markdown]
# #### How do you add a regression line to a scatter plot in Seaborn for the variables x and y in a DataFrame df?

# %%
# You can add a regression line to a scatter plot for the variables x and y using the regplot() function.
# Example:
# sns.regplot(x=[1, 2, 3], y=[4, 5, 6])
